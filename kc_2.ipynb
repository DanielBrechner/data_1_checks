# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('/Users/danielbrechner/data_1_checks/assets/evdataset.csv')
df.head()
# Out:
#      id        Make                                               link  \
# 0  1647     Genesis  https://ev-database.org/car/1647/Genesis-GV60-...
# 1  1493    Mercedes  https://ev-database.org/car/1493/Mercedes-EQB-...
# 2  1229     Porsche  https://ev-database.org/car/1229/Porsche-Tayca...
# 3  1252         BMW   https://ev-database.org/car/1252/BMW-i4-eDrive40
# 4  1534  Volkswagen  https://ev-database.org/car/1534/Volkswagen-ID...
#
#    City - Cold Weather  Highway - Cold Weather  Combined - Cold Weather  \
# 0                  390                     275                      330
# 1                  330                     235                      280
# 2                  400                     305                      350
# 3                  445                     340                      390
# 4                  440                     320                      380
#
#    City - Mild Weather  Highway - Mild Weather  Combined - Mild Weather  \
# ...

# %% [markdown]
# #Want to see which make of electric vehicles is the fastest or slowest?

# %%
sns.barplot(x=df['Make'], y=df['Acceleration 0 - 100 km/h'], )
plt.xticks(rotation = 90, );

# %% [markdown]
# ##Accoriding to this dataset, Porsche makes the fastest (0-100km/h) electric vehicle, while Dacia has the slowest acceleration rate.
